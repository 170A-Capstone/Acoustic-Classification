# %%
from utils.sql_utils import DB
from utils.data_utils import IDMT,MVD

db = DB(log=True)

idmt = IDMT(db,log=True)

idmt.data_visualization('distribution')
# Out:
# [IDMT]: Paths Acquired
# [IDMT]: Data distribution Plotted (0.86s)

# %%
idmt.data_visualization("correlation")
# Out:
# [IDMT]: Data correlation Plotted (0.31s)

# %%
mvd = MVD(db,log=True)

mvd.data_visualization('distribution')
# Out:
# [MVD]: Paths Acquired
# [MVD]: Data distribution Plotted (0.63s)

# %%
mvd.data_visualization("correlation")
# Out:
# [MVD]: Data correlation Plotted (0.18s)

# %%
pca_result = mvd.data_visualization("PCA")
# Out:
# [MVD]: Data PCA Plotted (0.43s)

# %%
pca_result
# Out:
# {'principal_components': array([[-1.94354195, -0.34440303,  0.59565207, ..., -0.06140004,
#          -0.01565334,  0.00346525],
#         [-1.40789125,  0.91655352, -0.10798395, ..., -0.15673416,
#           0.06449683, -0.00998726],
#         [-0.97815718, -0.77952638, -0.70312488, ..., -0.02955594,
#           0.0187336 , -0.02255893],
#         ...,
#         [ 0.27116906, -1.02001663, -0.88226856, ..., -0.09442342,
#           0.06452299, -0.07072008],
#         [ 1.75322554,  1.48352642,  2.2387742 , ...,  0.07614169,
#          -0.07369952, -0.03185038],
#         [ 2.45776193,  0.39963774, -2.20100544, ...,  0.04394839,
#          -0.08224906,  0.1362232 ]]),
#  'explained_variance_ratio': array([4.77661278e-01, 2.34454709e-01, 1.16137913e-01, 9.15602271e-02,
#         3.42219782e-02, 1.89346195e-02, 9.90240880e-03, 7.99991433e-03,
#         5.17999161e-03, 2.28421772e-03, 1.10157121e-03, 3.63423681e-04,
#         1.97748242e-04]),
#  'pca': PCA()}
