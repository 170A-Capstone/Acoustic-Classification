# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = './secom/secom.data'

df = pd.read_csv(file_path,delimiter=' ')

# %%
df.iloc[:,0].values.shape
# Out:
# (1566,)

# %%
plt.plot(df.iloc[:,0].values)

# %%
plt.plot(df.iloc[1].values)
