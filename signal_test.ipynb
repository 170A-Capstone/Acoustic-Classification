# %%
import utils.data_utils as du

# %%
import utils.sql_utils as su

# %%
db = su.DB()

# %%
mvd1 = du.Dataset(db,'/Users/cecima/Desktop/170B-Proj/MVD/')

# %%
mvd = du.MVD(db,'/Users/apple/Desktop/MVD/')
# Out:
# [MVD]: Paths Acquired

# %%
mvd.getFilePaths()
# Out:
# [MVD]: Paths Acquired
# ['Recording_1856_O_C.wav',
#  'Recording_133_A_M.wav',
#  'Recording_1418_A_M.wav',
#  'Recording_398_A_T.wav',
#  'Recording_47_O_C.wav',
#  'Recording_388_A_T.wav',
#  'Recording_1335_A_M.wav',
#  'Recording_1831_O_N.wav',
#  'Recording_1043_A_M.wav',
#  'Recording_1949_O_N.wav',
#  'Recording_1380_A_C.wav',
#  'Recording_1821_O_N.wav',
#  'Recording_936_O_C.wav',
#  'Recording_1959_O_N.wav',
#  'Recording_1870_A_N.wav',
#  'Recording_513_M_C.wav',
#  'Recording_245_A_M.wav',
#  'Recording_792_O_C.wav',
#  'Recording_1685_O_N.wav',
#  'Recording_1860_A_N.wav',
#  'Recording_1695_O_N.wav',
#  'Recording_1705_A_N.wav',
#  'Recording_213_H_T.wav',
#  'Recording_1888_O_N.wav',
#  'Recording_1898_O_N.wav',
#  'Recording_203_H_T.wav',
#  'Recording_1744_O_N.wav',
#  'Recording_612_A_T.wav',
#  'Recording_669_M_M.wav',
#  'Recording_602_A_T.wav',
#  'Recording_1404_A_C.wav',
#  'Recording_643_O_C.wav',
#  'Recording_1754_O_N.wav',
#  'Recording_679_M_M.wav',
# ...

# %%
mvd.uploadFeatures()
# Out:
# [MVD]: Features Extracted
# [MVD]: Features Uploaded (0.07s)

# %%
mvd.uploadSignals()
# Out:
# [MVD]: Signals Extracted (0.17s)
# [MVD]: Signals Uploaded (18.83s)

# %%
mvd.downloadSignals()
# Out:
# [MVD]: Data Queried (1.63s)
# [MVD]: Data Decoded (0.00s)
# [array([  57,    9,  -63, ...,  -44,  -95, -143], dtype=int16),
#  array([ 646,  750,  827, ..., -260,  -81,  230], dtype=int16),
#  array([-260, -286, -289, ...,    0,    0,    0], dtype=int16),
#  array([-300, -230, -630, ..., 4611, 2747, 1108], dtype=int16),
#  array([-123, -123, -108, ...,    0,    0,    0], dtype=int16),
#  array([-1243, -1320, -1196, ...,     0,     0,     0], dtype=int16),
#  array([339, 243, 178, ...,   0,   0,   0], dtype=int16),
#  array([-59, -62, -60, ..., -33, -42, -50], dtype=int16),
#  array([ 191,  294,  323, ...,  865, 1278, 1491], dtype=int16),
#  array([ 16,  36,  48, ...,  92, 340,  71], dtype=int16),
#  array([-173, -189, -173, ..., -183, -359, -131], dtype=int16),
#  array([103, 109, 117, ...,  13,  21,  12], dtype=int16),
#  array([-155, -224, -359, ...,  938,  739, -521], dtype=int16),
#  array([ -7, -22, -13, ..., -33, -65, -41], dtype=int16),
# ...

# %%
mvd.transformSignals('statistical')
# Out:
# [MVD]: Data Queried (1.80s)
# [MVD]: Data Decoded (0.00s)
# [MVD]: Data Transformed (31.82s)
# [MVD]: Features Uploaded (0.15s)

# %%
mvd.constructDataLoader('statistical')
# Out:
# [MVD]: Data Queried (0.17s)
# [MVD]: Data Transformed (0.00s)
# [((5.382644654013395e-08,
#    6.048139947355784e-09,
#    4.3540367753254217e-10,
#    2.4064077795567547e-06,
#    1.4119840639486929e-06,
#    6.848314421252733e-07,
#    2.681428300397719e-07,
#    4.27614150593742e-07,
#    1.3753024703202666e-10,
#    0.9999999999718211,
#    6.91712724165335e-06,
#    2.083278623299478e-10,
#    4.684214441784219e-10),
#   [0, 1, 0, 0]),
#  ((2.4516329242200678e-09,
#    8.964045519156998e-09,
#    2.8013584390113716e-10,
#    1.5112145695959377e-06,
#    1.4615248289657808e-06,
#    3.0245344690569804e-07,
#    1.6448435338799943e-08,
#    4.1108750725410027e-07,
#    4.5083275704152694e-11,
#    0.999999999989319,
#    4.0842954254670335e-06,
#    1.6236347565533634e-10,
#    1.6622760279082357e-10),
#   [0, 0, 1, 0]),
#  ((7.406485246279581e-09,
#    3.381331454703489e-09,
#    1.8890696295537584e-10,
#    2.2682303557882246e-06,
#    2.448096693623845e-06,
# ...

# %%
mvd.transformSignals('librosa')
# Out:
# [MVD]: Data Queried (1.60s)
# [MVD]: Data Decoded (0.00s)
# [MVD]: Data Transformed (1114.63s)
# [MVD]: Features Uploaded (0.11s)

# %%
mvd.constructDataLoader('feature')
# Out:
# [MVD]: Data Queried (0.16s)
# [MVD]: Data Transformed (0.00s)
# [((-1.4266004879780485e-08,
#    0.06644810849138351,
#    0.9928818957173018,
#    0.00012371125889463745,
#    0.09884419421624273),
#   [0, 1, 0, 0]),
#  ((-7.666237753093135e-09,
#    0.004505635131024803,
#    0.9976735260350962,
#    7.883775599738678e-05,
#    0.06802373472084952),
#   [0, 0, 1, 0]),
#  ((-8.692339403058466e-09,
#    0.03253628151577031,
#    0.99717527583859,
#    9.440044160767274e-05,
#    0.06769675568234473),
#   [0, 0, 1, 0]),
#  ((-2.3024382863154586e-09,
#    0.010930957013910761,
#    0.9998122782488625,
#    2.889151518737223e-05,
#    0.015997550026776202),
#   [0, 0, 0, 1]),
#  ((-2.1521524052925728e-08,
#    0.0,
#    0.9805110984832138,
#    0.0002540259189368946,
#    0.19646353662212596),
#   [0, 1, 0, 0]),
#  ((-2.382685612676874e-09,
#    0.007561496913485787,
#    0.9998090821227525,
#    1.2627405928617559e-05,
#    0.018017294742413655),
#   [0, 0, 0, 1]),
# ...
